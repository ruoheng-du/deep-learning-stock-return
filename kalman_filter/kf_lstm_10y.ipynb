# %%
# !pip install pykalman
# Out:
# Collecting pykalman
#   Downloading pykalman-0.9.5.tar.gz (228 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.9/228.9 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pykalman
#   Building wheel for pykalman (setup.py) ... done
#   Created wheel for pykalman: filename=pykalman-0.9.5-py3-none-any.whl size=48442 sha256=16f27ecae5ea5fd12603a377369568dbcda212d55ef5196759d7df1a8deb36d1
#   Stored in directory: /root/.cache/pip/wheels/76/33/ef/5f332226e13a5089c6dd4b01cc2bcb59491d18f955fa2d3807
# Successfully built pykalman
# Installing collected packages: pykalman
# Successfully installed pykalman-0.9.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
from pykalman import KalmanFilter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/# DS Capstone/3 LSTM
# Out:
# /content/drive/MyDrive/# DS Capstone/3 LSTM

# %%
# Load file
file_path = './data_10y.xlsx'
dataset = pd.read_excel(file_path, header=0, index_col=False)
dataset.drop(dataset.tail(1).index,inplace=True)
dataset.drop(dataset.columns[0], axis=1, inplace=True)
df = dataset['shci_10y']

# %%
kf = KalmanFilter(
    transition_matrices = [1],
    observation_matrices = [1],
    initial_state_mean = 0,
    initial_state_covariance = 1,
    observation_covariance=1,
    transition_covariance=0.01
)

# %%
state_means, _ = kf.filter(df.values)
state_means = pd.Series(state_means.flatten(), index=df.index)

pyplot.plot(df, color='red', label='Return')
pyplot.plot(state_means, color='blue', label='Kalman')
pyplot.title('Kalman Filter Estimate of Average')
pyplot.xlabel('Time')
pyplot.ylabel('SHCI return')
pyplot.legend()
pyplot.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from math import sqrt
from numpy import concatenate

# %%
dataset.insert(loc=1, column='kalman', value=state_means)

# %%
dataset.drop(dataset.columns[0], axis=1, inplace=True)

# %%
values = dataset.values
print(dataset.head())
print(dataset.tail())
# Out:
#      kalman    sp_10y   nas_10y   vix_10y    rf_10y  forward_shci_10y
# 0 -0.005835 -0.005511 -0.005803 -0.000614  0.001406         -0.000656
# 1 -0.004085 -0.013780 -0.012707  0.075599 -0.017314         -0.012691
# 2 -0.006306  0.008490  0.006635 -0.049714 -0.011905         -0.013920
# 3 -0.007915  0.012832  0.013192 -0.089597  0.041446         -0.028287
# 4 -0.011608  0.014784  0.013213 -0.117267 -0.025112          0.006368
#         kalman    sp_10y   nas_10y   vix_10y    rf_10y  forward_shci_10y
# 2344 -0.001735 -0.011222 -0.012620  0.076700 -0.005647         -0.012781
# 2345 -0.002786 -0.007319 -0.006058  0.080950  0.005679         -0.001089
# 2346 -0.002624  0.008758  0.017136 -0.044433  0.025544          0.003511
# 2347 -0.002041  0.013049  0.021862 -0.062173 -0.001049          0.000857
# 2348 -0.001765  0.000017  0.003217 -0.027298 -0.028871         -0.006095

# %%
# Split into train, val, test sets 8:1:1
n_train = int(len(dataset) * 0.8)
train = values[:n_train, :]
val_test = values[n_train:, :]

n_val = int(len(val_test) * 0.5)
val = val_test[:n_val, :]
test = val_test[n_val:, :]

# Print the shapes of train, val, and test sets
print("Dataset shape:", dataset.shape)
print("Train set shape:", train.shape)
print("Validation set shape:", val.shape)
print("Test set shape:", test.shape)
# Out:
# Dataset shape: (2349, 6)
# Train set shape: (1879, 6)
# Validation set shape: (235, 6)
# Test set shape: (235, 6)

# %%
# Normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train = scaler.fit_transform(train)
scaled_val = scaler.transform(val)
scaled_test = scaler.transform(test)

# %%
# Split into input and outputs
train_X, train_y = scaled_train[:, :-1], scaled_train[:, -1]
val_X, val_y = scaled_val[:, :-1], scaled_val[:, -1]
test_X, test_y = scaled_test[:, :-1], scaled_test[:, -1]

print("train_X", train_X.shape)
print("train_y", train_y.shape)
print("val_X", val_X.shape)
print("val_y", val_y.shape)
print("test_X", test_X.shape)
print("test_y", test_y.shape)
# Out:
# train_X (1879, 5)
# train_y (1879,)
# val_X (235, 5)
# val_y (235,)
# test_X (235, 5)
# test_y (235,)

# %%
# Reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# Model

# def network
model = Sequential()
model.add(LSTM(128, activation='relu', input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=128, validation_data=(val_X, val_y), verbose=2, shuffle=False)

# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/50
# 15/15 - 6s - loss: 0.5404 - val_loss: 0.4757 - 6s/epoch - 408ms/step
# Epoch 2/50
# 15/15 - 0s - loss: 0.4257 - val_loss: 0.3491 - 196ms/epoch - 13ms/step
# Epoch 3/50
# 15/15 - 0s - loss: 0.2813 - val_loss: 0.1776 - 180ms/epoch - 12ms/step
# Epoch 4/50
# 15/15 - 0s - loss: 0.1084 - val_loss: 0.0623 - 335ms/epoch - 22ms/step
# Epoch 5/50
# 15/15 - 0s - loss: 0.0770 - val_loss: 0.0546 - 225ms/epoch - 15ms/step
# Epoch 6/50
# 15/15 - 0s - loss: 0.0673 - val_loss: 0.0556 - 318ms/epoch - 21ms/step
# Epoch 7/50
# 15/15 - 0s - loss: 0.0658 - val_loss: 0.0545 - 235ms/epoch - 16ms/step
# Epoch 8/50
# 15/15 - 0s - loss: 0.0656 - val_loss: 0.0547 - 261ms/epoch - 17ms/step
# Epoch 9/50
# 15/15 - 0s - loss: 0.0656 - val_loss: 0.0545 - 198ms/epoch - 13ms/step
# Epoch 10/50
# 15/15 - 0s - loss: 0.0655 - val_loss: 0.0546 - 211ms/epoch - 14ms/step
# Epoch 11/50
# 15/15 - 0s - loss: 0.0655 - val_loss: 0.0545 - 182ms/epoch - 12ms/step
# Epoch 12/50
# 15/15 - 0s - loss: 0.0655 - val_loss: 0.0544 - 263ms/epoch - 18ms/step
# Epoch 13/50
# 15/15 - 0s - loss: 0.0654 - val_loss: 0.0544 - 297ms/epoch - 20ms/step
# Epoch 14/50
# 15/15 - 0s - loss: 0.0654 - val_loss: 0.0544 - 220ms/epoch - 15ms/step
# Epoch 15/50
# 15/15 - 0s - loss: 0.0654 - val_loss: 0.0544 - 268ms/epoch - 18ms/step
# Epoch 16/50
# 15/15 - 0s - loss: 0.0653 - val_loss: 0.0543 - 255ms/epoch - 17ms/step
# Epoch 17/50
# 15/15 - 0s - loss: 0.0653 - val_loss: 0.0543 - 248ms/epoch - 17ms/step
# Epoch 18/50
# 15/15 - 0s - loss: 0.0652 - val_loss: 0.0542 - 258ms/epoch - 17ms/step
# Epoch 19/50
# 15/15 - 0s - loss: 0.0652 - val_loss: 0.0543 - 293ms/epoch - 20ms/step
# Epoch 20/50
# 15/15 - 0s - loss: 0.0652 - val_loss: 0.0542 - 390ms/epoch - 26ms/step
# Epoch 21/50
# 15/15 - 0s - loss: 0.0651 - val_loss: 0.0542 - 415ms/epoch - 28ms/step
# Epoch 22/50
# 15/15 - 0s - loss: 0.0651 - val_loss: 0.0541 - 419ms/epoch - 28ms/step
# Epoch 23/50
# 15/15 - 0s - loss: 0.0651 - val_loss: 0.0541 - 267ms/epoch - 18ms/step
# Epoch 24/50
# 15/15 - 0s - loss: 0.0650 - val_loss: 0.0540 - 311ms/epoch - 21ms/step
# Epoch 25/50
# 15/15 - 0s - loss: 0.0649 - val_loss: 0.0540 - 376ms/epoch - 25ms/step
# Epoch 26/50
# 15/15 - 0s - loss: 0.0649 - val_loss: 0.0540 - 387ms/epoch - 26ms/step
# Epoch 27/50
# 15/15 - 0s - loss: 0.0648 - val_loss: 0.0540 - 397ms/epoch - 26ms/step
# Epoch 28/50
# 15/15 - 0s - loss: 0.0648 - val_loss: 0.0540 - 395ms/epoch - 26ms/step
# Epoch 29/50
# 15/15 - 0s - loss: 0.0648 - val_loss: 0.0539 - 382ms/epoch - 25ms/step
# Epoch 30/50
# 15/15 - 0s - loss: 0.0647 - val_loss: 0.0539 - 270ms/epoch - 18ms/step
# Epoch 31/50
# 15/15 - 0s - loss: 0.0646 - val_loss: 0.0541 - 310ms/epoch - 21ms/step
# Epoch 32/50
# 15/15 - 0s - loss: 0.0646 - val_loss: 0.0544 - 310ms/epoch - 21ms/step
# Epoch 33/50
# 15/15 - 0s - loss: 0.0647 - val_loss: 0.0544 - 327ms/epoch - 22ms/step
# Epoch 34/50
# 15/15 - 0s - loss: 0.0646 - val_loss: 0.0543 - 372ms/epoch - 25ms/step
# Epoch 35/50
# 15/15 - 1s - loss: 0.0646 - val_loss: 0.0542 - 523ms/epoch - 35ms/step
# Epoch 36/50
# 15/15 - 0s - loss: 0.0645 - val_loss: 0.0541 - 375ms/epoch - 25ms/step
# Epoch 37/50
# 15/15 - 0s - loss: 0.0645 - val_loss: 0.0540 - 418ms/epoch - 28ms/step
# Epoch 38/50
# 15/15 - 0s - loss: 0.0644 - val_loss: 0.0539 - 291ms/epoch - 19ms/step
# Epoch 39/50
# 15/15 - 0s - loss: 0.0644 - val_loss: 0.0539 - 393ms/epoch - 26ms/step
# Epoch 40/50
# 15/15 - 0s - loss: 0.0643 - val_loss: 0.0539 - 332ms/epoch - 22ms/step
# Epoch 41/50
# 15/15 - 0s - loss: 0.0643 - val_loss: 0.0539 - 335ms/epoch - 22ms/step
# Epoch 42/50
# 15/15 - 0s - loss: 0.0643 - val_loss: 0.0540 - 329ms/epoch - 22ms/step
# Epoch 43/50
# 15/15 - 0s - loss: 0.0643 - val_loss: 0.0539 - 257ms/epoch - 17ms/step
# Epoch 44/50
# 15/15 - 0s - loss: 0.0642 - val_loss: 0.0540 - 377ms/epoch - 25ms/step
# Epoch 45/50
# 15/15 - 0s - loss: 0.0642 - val_loss: 0.0540 - 345ms/epoch - 23ms/step
# Epoch 46/50
# 15/15 - 0s - loss: 0.0642 - val_loss: 0.0539 - 213ms/epoch - 14ms/step
# Epoch 47/50
# 15/15 - 0s - loss: 0.0642 - val_loss: 0.0540 - 198ms/epoch - 13ms/step
# Epoch 48/50
# 15/15 - 0s - loss: 0.0642 - val_loss: 0.0541 - 182ms/epoch - 12ms/step
# Epoch 49/50
# 15/15 - 0s - loss: 0.0642 - val_loss: 0.0540 - 181ms/epoch - 12ms/step
# Epoch 50/50
# 15/15 - 0s - loss: 0.0642 - val_loss: 0.0539 - 198ms/epoch - 13ms/step

# %%
# Evaluate the model and calculate Train RMSE
train_yhat = model.predict(train_X)
train_yhat_copies_array = np.repeat(train_yhat, 6, axis=-1)
inv_train_yhat = scaler.inverse_transform(np.reshape(train_yhat_copies_array, (len(train_yhat), 6)))[:, 0]
train_original_copies_array = np.repeat(train_y, 6, axis=-1)
inv_train_y = scaler.inverse_transform(np.reshape(train_original_copies_array, (len(train_y), 6)))[:, 0]
train_rmse = sqrt(mean_squared_error(inv_train_yhat, inv_train_y))
print('Train RMSE: %.4f' % train_rmse)
# Out:
# 59/59 [==============================] - 1s 8ms/step
# Train RMSE: 0.0033

# %%
# Plot and check train set
pyplot.plot(inv_train_y, color='red', label='Real')
pyplot.plot(inv_train_yhat, color='green', label='Model')
pyplot.title('Train Dataset')
pyplot.xlabel('Time')
pyplot.ylabel('SHCI return')
pyplot.legend()
pyplot.show()

# %%
# Make predictions
yhat = model.predict(test_X)
yhat_copies_array = np.repeat(yhat, 6, axis = -1)
inv_yhat = scaler.inverse_transform(np.reshape(yhat_copies_array, (len(yhat), 6)))[:, 0]
original_copies_array = np.repeat(test_y, 6, axis=-1)
inv_y = scaler.inverse_transform(np.reshape(original_copies_array, (len(test_y), 6)))[:, 0]
rmse = sqrt(mean_squared_error(inv_yhat, inv_y))
print('Test RMSE: %.4f' % rmse)
# Out:
# 8/8 [==============================] - 0s 5ms/step
# Test RMSE: 0.0022

# %%
# plot predicted vs actual
pyplot.plot(inv_y, color='red', label='Original')
pyplot.plot(inv_yhat, color='blue', label='Predicted')
pyplot.title('SHCI return prediction')
pyplot.xlabel('Time')
pyplot.ylabel('SHCI return')
pyplot.legend()
pyplot.show()
